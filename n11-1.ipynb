# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time

'''
Bu kısım çalışmaktadır fakat çok uzun sürdüğü için ve engele takıldığı için tercih edilmemiştir
#headers={"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36"}

for i in range(1,5):
       
    url="https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg="
    yeni_url = url + str(i)
    time.sleep(1) #1 saniye uyuyup yeniden istek göndermeye yarar
    r=requests.get(yeni_url)
    
    soup = BeautifulSoup(r.content,"lxml")
    st0=soup.find_all("span",attrs={"class":"textImg followBtn"})
    
    for span in st0:
        st6=(span['data-productid']) #tüm ürün idleri
        abc="&productId="
        abc1="&fbclid=IwAR1AMqdhr8vVLz461zBsuDIbs5ftdq45IlWv2derSVngCXHAea2hxPR1HEE"
            
        st7=abc+st6+abc1     #tüm ürünlerin linkleri
       
        for sayfaNo in range(1,3):
            urunler="https://www.n11.com/component/render/productReviews?page="+str(sayfaNo)+st7
            urun=urunler+st7   
            time.sleep(1)
            r=requests.get(urun)
            soup1 = BeautifulSoup(r.content, "lxml")
            yorum=soup.find_all("li",attrs={"class":"comment"})
            liste = []
            for st1 in yorum:
                st2=st1.find("div",attrs={"class":"ratingCont"})
                st3=st2.find("span",attrs={"class":"rating"})
        
                st4=int(st3['class'][1].replace("r",""))/100 
                #d=soup1.find("div",attrs={"class":"holder"})
                d1=st1.find("p").text.strip().replace("\n","")
            liste.append([d1,st4])
            print(d1,"=",st4)
            
            
            
            df = pd.DataFrame(liste)
            df.columns=["yorum","puan"]
            df.to_csv('cepyorum.csv',encoding='utf-8')
            df
'''
# Out:
# '\n#headers={"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36"}\n\nfor i in range(1,5):\n       \n    url="https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg="\n    yeni_url = url + str(i)\n    time.sleep(1) #1 saniye uyuyup yeniden istek göndermeye yarar\n    r=requests.get(yeni_url)\n    \n    soup = BeautifulSoup(r.content,"lxml")\n    st0=soup.find_all("span",attrs={"class":"textImg followBtn"})\n    \n    for span in st0:\n        st6=(span[\'data-productid\']) #tüm ürün idleri\n        abc="&productId="\n        abc1="&fbclid=IwAR1AMqdhr8vVLz461zBsuDIbs5ftdq45IlWv2derSVngCXHAea2hxPR1HEE"\n            \n        st7=abc+st6+abc1     #tüm ürünlerin linkleri\n       \n        for sayfaNo in range(1,3):\n            urunler="https://www.n11.com/component/render/productReviews?page="+str(sayfaNo)+st7\n            urun=urunler+st7   \n            time.sleep(1)\n            r=requests.get(urun)\n            so
# ...

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=453514924"
for i in range(1,50):
    yeni_adres=a+str(i)+b
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        #d=soup1.find("div",attrs={"class":"holder"})
        target=st1.find("p").text
        #target=duzelt(st1.find("p").text.strip().replace("\n",""))
        
        liste.append([target,st4])
        print(target,"=",st4)
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum.csv',encoding='utf-8')
    df
# Out:
#   File "<ipython-input-90-ad38d307c20e>", line 18
#     liste.append([target,st4])
#     ^
# SyntaxError: invalid syntax

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=416127257"
for i in range(1,337):
    yeni_adres=a+str(i)+b
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        #d=soup1.find("div",attrs={"class":"holder"})
        target=st1.find("p")
        #.text.strip().replace("\n","")
        liste.append([target,st4])
        print(target,"=",st4)
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum1.csv')
    df
# Out:
# <p>Ürünler elime ulaştı. Fiyatına göre kaliteli, 3 adet aldım üçüde sağlam
# geldi. Rahatlıkla alabilirsiniz.</p> = 1.0
# <p>ben beğendim arkadaşlar</p> = 1.0
# <p>Hızlı kargo Güzel değil</p> = 0.4
# <p>1 haftada normal kullanımda kırıldı.  Daha önce farklı ürünler
# kullandım, 5-6 ay götürüyordu. Bu ürün dayanmadı. Kesinlikle düşürme,
# çarpma, sıkıştırma olmadı. Cebimde alt kısımdan, home bölümünden çatladı
# ve aynı gün çatlaklar büyüdü.</p> = 0.2
# <p>ürün anlatıldığı gibi geldi</p> = 1.0
# <p>Normalde bu üründen alıp taktıklarımda hava kabarcıkları oluşuyordu
# ancak bu ürün gayet güzel oldu, teşekkürler</p> = 1.0
# <p>Ürün beklediğin den daha kaliteli geliyor</p> = 1.0
# <p>Parasını hak etmeyen bir ürün paketleme özensiz gelen ürün ekrana tam
# oturmasını geçiyorum yapışmıyor sürekli hava kalıyor zaten ekrana küçük
# geliyor alacak olan arkadaşlar başka bir mağazadan almalarını ısrarla
# tavsiye ederim SAKIN ALMAYIN !!!!</p> = 0.2
# ...

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=416127246"
for i in range(1,186):
    yeni_adres=a+str(i)+b
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        #d=soup1.find("div",attrs={"class":"holder"})
        target=st1.find("p")
        #.text.strip().replace("\n","")
        liste.append([target,st4])
        print(target,"=",st4)
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum2.csv')
    df
# Out:
# <p>Bir hafta oldu takalı asla düşürmeme ragmen ucundan çatladı ürün</p> = 0.2
# <p>Gayet kaliteli ve uygun fiyatlı.</p> = 1.0
# <p>Mağaza iyi hemen soruları cevaplıyor ama görseldeki ürün ile gelen ürün
# arasında dağlar kadar fark var gelen ürün kalitesiz</p> = 0.2
# <p>Kenarları parmağıma değiyor ekranı tam kaplamadı. Ayrıca dokunma
# hissiyatı iyi değil. Parmak izi çok bırakıyor</p> = 0.4
# <p>Ürün elime belirlenen sürede ulaştı. Fakat telefona takınca yakınlık
# sensörünü etkilediğini yani kapattığını gördüm. Buda ciddi bir sorun.
# Dolayısı ile çıkarıp çöpe attım. Kısacası ürün çöp.</p> = 0.2
# <p>Ürünü aldığım ilk gün çatladı maalesef. Cebimde anahtarla birlikte
# duruyordu. Herhangi bir hava boşluğu bırakmamama rağmen çatladı, çok
# kaliteli değil.</p> = 0.4
# <p>Görselde ki gibi ekranın üst kısmı telefonun formunda değil.  sadece
# çevresi siyah ve sıradan bir kırılmaz cam şeklinde.</p> = 0.6
# <p>Ürün kalitelisi gayet güzel, paketlemenin özenli olmasına rağmen kargo
# ...

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=141894725"
for i in range(1,194):
    yeni_adres=a+str(i)+b
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum4.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=359663339"
for i in range(1,158):
    yeni_adres=a+str(i)+b
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum5.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=152653484"
for i in range(1,133):
    yeni_adres=a+str(i)+b
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum6.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=312799187"
for i in range(1,172):
    yeni_adres=a+str(i)+b
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum7.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=202454404"
for i in range(1,126):
    yeni_adres=a+str(i)+b
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum8.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=432043269"
for i in range(1,86):
    yeni_adres=a+str(i)+b
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum9.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=115992604"
for i in range(1,108):
    yeni_adres=a+str(i)+b
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum10.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=127483852"
for i in range(1,105):
    yeni_adres=a+str(i)+b
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum11.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=407998637"
for i in range(1,152):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum12.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=325424743"
for i in range(1,80):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum13.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=254051147"
for i in range(1,87):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum14.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=312793145"
for i in range(1,85):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum15.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=325697956"
for i in range(1,65):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum16.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=319829314"
for i in range(1,85):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum17.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=310828030"
for i in range(1,151):
    yeni_adres=a+str(i)+b
    
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum18.csv',encoding='utf-8')
    df

# %%
186103136 89
291954498 67
405883465 39
179202748 51
155449375 43

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=52836223"
for i in range(1,76):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum19.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=88327956"
for i in range(1,62):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum20.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=142909510"
for i in range(1,75):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum21.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=88305792"
for i in range(1,59):
    yeni_adres=a+str(i)+b
    
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum22.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=361828215"
for i in range(1,73):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum23.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=416127253"
for i in range(1,77):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum24.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=432042579"
for i in range(1,53):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum25.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=162424538"
for i in range(1,66):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum26.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=310828030"
for i in range(1,89):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum27.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=310828030"
for i in range(1,67):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum28.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=310828030"
for i in range(1,39):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum29.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=310828030"
for i in range(1,51):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum30.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=310828030"
for i in range(1,43):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum31.csv',encoding='utf-8')
    df

# %%
167147574 54
302745712 36
354249758 44
411273719 46
199695772 24
214892159 104
86012928 78
213515379 54
152682695 70
214891764 60

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=167147574"
for i in range(1,54):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum32.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=302745712"
for i in range(1,36):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum33.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=354249758"
for i in range(1,44):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum34.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=411273719"
for i in range(1,46):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum35.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=199695772"
for i in range(1,24):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum36.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=214892159"
for i in range(1,104):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum37.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=86012928"
for i in range(1,78):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum38.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=213515379"
for i in range(1,54):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum39.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=152682695"
for i in range(1,70):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum40.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=214891764"
for i in range(1,60):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum41.csv',encoding='utf-8')
    df

# %%
299697888 63
220693610 50
249333352 44
296400951 26
290864127 34
99925701 209
273743897 196
271010908 156
410046280 128
389023334 110
252655114 110
285862697 103
199915355 102
303164001 102
252093668 90
238339646 122
341370449 56
474551694 59
323867489 43
102001067 143
202326725 99
202877063 98
133371103 65

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=299697888"
for i in range(1,63):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum42.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=220693610"
for i in range(1,50):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum43.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=249333352"
for i in range(1,44):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum44.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=296400951"
for i in range(1,26):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum45.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=290864127"
for i in range(1,34):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum46.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=99925701"
for i in range(1,209):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum47.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=273743897"
for i in range(1,196):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum48.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=271010908"
for i in range(1,156):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum49.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=410046280"
for i in range(1,128):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum50.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=389023334"
for i in range(1,110):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum51.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=252655114"
for i in range(1,110):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum52.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=285862697"
for i in range(1,103):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum53.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=199915355"
for i in range(1,102):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum54.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=303164001"
for i in range(1,102):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum55.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=252093668"
for i in range(1,90):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum56.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=238339646"
for i in range(1,122):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum57.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=341370449"
for i in range(1,56):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum58.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=474551694"
for i in range(1,59):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum59.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=323867489"
for i in range(1,43):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum60.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=102001067"
for i in range(1,143):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum61.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=202326725"
for i in range(1,99):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum62.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=202877063"
for i in range(1,98):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum63.csv',encoding='utf-8')
    df

# %%
liste = []
a="https://www.n11.com/component/render/productReviews?page="
b="&productId=133371103"
for i in range(1,65):
    yeni_adres=a+str(i)+b
    time.sleep(1)
    r=requests.get(yeni_adres)
    soup = BeautifulSoup(r.content, "lxml")
    yorum=soup.find_all("li",attrs={"class":"comment"})
    for st1 in yorum:
        st2=st1.find("div",attrs={"class":"ratingCont"})
        st3=st2.find("span",attrs={"class":"rating"})
        st4=int(st3['class'][1].replace("r",""))/100
        
        
        target=st1.find("p")
        
        liste.append([target,st4])
        
    df = pd.DataFrame(liste)
    df.columns=['yorum','puan']
    df.to_csv('cepyorum64.csv',encoding='utf-8')
    df
